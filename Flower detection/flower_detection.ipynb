# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="config.yaml", epochs=100)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results

# %%
results = model(['E:/sample_project/flowers/flowers final/flowers/rose/229488796_21ac6ee16d_n.jpg'])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs
# Out:
# 0: 480x640 7 flowers, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
img = 'E:/sample_project/flowers/flowers final/flowers/rose/229488796_21ac6ee16d_n.jpg'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 results = results.cuda()
#       2 results = results.cpu()
#       3 results = results.to('cpu')
#
# AttributeError: 'list' object has no attribute 'cuda'

# %%
results = model(img)
boxes = results[0].boxes
box = boxes[0]  # returns one box
box.xyxy
# Out:
# image 1/1 E:\sample_project\flowers\flowers final\flowers\rose\229488796_21ac6ee16d_n.jpg: 480x640 7 flowers, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# tensor([[  5.4173,  77.9379,  83.3095, 194.6569]])

# %%
boxes.xyxy  # box with xyxy format, (N, 4)
boxes.xywh  # box with xywh format, (N, 4)
boxes.xyxyn  # box with xyxy format but normalized, (N, 4)
boxes.xywhn  # box with xywh format but normalized, (N, 4)
boxes.conf  # confidence score, (N, )
boxes.cls  # cls, (N, )
boxes.data  # raw bboxes tensor, (N, 6) or boxes.boxes
# Out:
# tensor([[5.4173e+00, 7.7938e+01, 8.3310e+01, 1.9466e+02, 4.2538e-01, 0.0000e+00],
#         [1.7642e+02, 1.7015e+01, 2.8734e+02, 1.2839e+02, 3.7463e-01, 0.0000e+00],
#         [1.8092e+02, 6.3708e+00, 2.5993e+02, 1.2168e+02, 3.4832e-01, 0.0000e+00],
#         [0.0000e+00, 7.5245e+01, 1.1515e+02, 1.8265e+02, 3.4037e-01, 0.0000e+00],
#         [0.0000e+00, 7.6341e+01, 6.5525e+01, 1.9541e+02, 2.8619e-01, 0.0000e+00],
#         [1.9895e+02, 4.2221e+01, 3.2000e+02, 1.5166e+02, 2.7655e-01, 0.0000e+00],
#         [1.8422e+02, 2.6666e+01, 3.0796e+02, 1.3566e+02, 2.6547e-01, 0.0000e+00]])

# %%
# Out:
# image 1/1 E:\sample_project\flowers\flowers final\flowers\rose\229488796_21ac6ee16d_n.jpg: 480x640 7 flowers, 114.0ms
# Speed: 4.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 results = model(img)
#       2 keypoints = results[0].keypoints  # Masks object
# ----> 3 keypoints.xy  # x, y keypoints (pixels), (num_dets, num_kpts, 2/3), the last dimension can be 2 or 3, depends the model.
#       4 keypoints.xyn  # x, y keypoints (normalized), (num_dets, num_kpts, 2/3)
#       5 keypoints.conf  # confidence score(num_dets, num_kpts) of each keypoint if the last dimension is 3.
#
# AttributeError: 'NoneType' object has no attribute 'xy'

# %%
results = model(img)

# Check if keypoints are detected
if results[0].keypoints is not None:
    keypoints = results[0].keypoints
    # Access keypoints information safely
    xy = keypoints.xy
    xyn = keypoints.xyn
    conf = keypoints.conf
else:
    print("No keypoints detected in the image.")
# Out:
# image 1/1 E:\sample_project\flowers\flowers final\flowers\rose\229488796_21ac6ee16d_n.jpg: 480x640 7 flowers, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No keypoints detected in the image.

# %%
# Out:
# image 1/1 E:\sample_project\flowers\flowers final\flowers\rose\229488796_21ac6ee16d_n.jpg: 480x640 7 flowers, 78.5ms
# Speed: 1.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 res = model(img)
#       2 res_plotted = res[0].plot()
# ----> 3 cv2.imshow("result", res_plotted)
#
# NameError: name 'cv2' is not defined

# %%
import cv2
import matplotlib.pyplot as plt

# %%
res = model(img)
res_plotted = res[0].plot()
cv2.imshow("result", res_plotted)
# Out:
# image 1/1 E:\sample_project\flowers\flowers final\flowers\rose\229488796_21ac6ee16d_n.jpg: 480x640 7 flowers, 75.0ms
# Speed: 1.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
plt.imshow(res_plotted)
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
# Save the image to a file
cv2.imwrite('output_image.jpg', res_plotted)

# Open the image with the default image viewer
import os
os.system('start output_image.jpg')
# Out:
# 0
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "e:\sample_project\env\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "e:\sample_project\env\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "e:\sample_project\env\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "e:\sample_project\env\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
# Assuming res_plotted is an image in NumPy array format
plt.imshow(res_plotted)
plt.axis('off')  # Turn off axis labels
plt.show(block=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Assuming res_plotted is an image in NumPy array format
# ----> 2 plt.imshow(res_plotted)
#       3 plt.axis('off')  # Turn off axis labels
#       4 plt.show(block=True)
#
# NameError: name 'plt' is not defined
